# %% [markdown]
# Newtons metode

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return np.exp(-x/4) * np.arctan(x)

# (np.arctan(x))*(np.exp(-x(4))

#np.arctan(x) - (4/(x**2 + 1)) Der 

def f_der(x):
    return 

def f_doubleDer(x):
    return (4/(x**2 + 1) + ((8*x)/(1+x**2)**2))
    
x = np.linspace(-5, 10, 50)
plt.plot(x, f(x))
plt.plot(x, f_der(x))
plt.plot(x, f_doubleDer(x))
plt.grid()
